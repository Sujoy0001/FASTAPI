# %%
import os
from dotenv import load_dotenv

# %%
from openai import OpenAI

# %%
print("Loading environment variables from .env file...")
load_dotenv()
print(nvidia_api_key := os.getenv("nvidia_api_key"))
# Out:
# Loading environment variables from .env file...
# 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

# %%
client = OpenAI(
    base_url = "https://intergrate.api.nvidia.com/v1",
    api_key = os.getenv("nvidia_api_key")
)

# %%
completion = client.chat.completions.create(
    model="openai/gtp-oss-120b",
    messages=[
        {"role": "user", "content": ""}
    ],
    temperature=0.7,
    max_tokens=1000,
    top_p=0.9,
    stream=False
)

reasoning = getattr(completion.choices[0].message, "reasoning_content", None)

if reasoning:
    print("Reasoning content:", reasoning)
print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1036 try:
# -> 1037     response = self._send_request(
#    1038         request,
#    1039         stream=stream or self._should_stream_response_body(request=request),
#    1040         **kwargs,
#    1041     )
#    1042 except httpx.TimeoutException as err:
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_client.py:478, in OpenAI._send_request(self, request, stream, **kwargs)
#     470 @override
#     471 def _send_request(
#     472     self,
#    (...)    476     **kwargs: Unpack[HttpxSendArgs],
#     477 ) -> httpx.Response:
# --> 478     response = self._send_with_auth_retry(request, stream=stream, **kwargs)
#     479     if self._provider_runtime is not None and self._provider_runtime.normalize_response is not None:
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_client.py:456, in OpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     454         used_workload_identity_auth = True
# --> 456 response = super()._send_request(request, stream=stream, **kwargs)
#     457 if (
#     458     response.status_code == 401
#     459     and self._workload_identity_auth is not None
#     460     and used_workload_identity_auth
#     461     and not retried
#     462 ):
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:964, in SyncAPIClient._send_request(self, request, stream, **kwargs)
#     957 def _send_request(
#     958     self,
#     959     request: httpx.Request,
#    (...)    962     **kwargs: Unpack[HttpxSendArgs],
#     963 ) -> httpx.Response:
# --> 964     return self._client.send(request, stream=stream, **kwargs)
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 completion = client.chat.completions.create(
#       2     model="openai/gtp-oss-120b",
#       3     messages=[
#       4         {"role": "user", "content": ""}
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\resources\chat\completions\completions.py:1281, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1232 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1233 def create(
#    1234     self,
#    (...)   1278     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1279 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1280     validate_response_format(response_format)
# -> 1281     return self._post(
#    1282         "/chat/completions",
#    1283         body=maybe_transform(
#    1284             {
#    1285                 "messages": messages,
#    1286                 "model": model,
#    1287                 "audio": audio,
#    1288                 "frequency_penalty": frequency_penalty,
#    1289                 "function_call": function_call,
#    1290                 "functions": functions,
#    1291                 "logit_bias": logit_bias,
#    1292                 "logprobs": logprobs,
#    1293                 "max_completion_tokens": max_completion_tokens,
#    1294                 "max_tokens": max_tokens,
#    1295                 "metadata": metadata,
#    1296                 "modalities": modalities,
#    1297                 "moderation": moderation,
#    1298                 "n": n,
#    1299                 "parallel_tool_calls": parallel_tool_calls,
#    1300                 "prediction": prediction,
#    1301                 "presence_penalty": presence_penalty,
#    1302                 "prompt_cache_key": prompt_cache_key,
#    1303                 "prompt_cache_options": prompt_cache_options,
#    1304                 "prompt_cache_retention": prompt_cache_retention,
#    1305                 "reasoning_effort": reasoning_effort,
#    1306                 "response_format": response_format,
#    1307                 "safety_identifier": safety_identifier,
#    1308                 "seed": seed,
#    1309                 "service_tier": service_tier,
#    1310                 "stop": stop,
#    1311                 "store": store,
#    1312                 "stream": stream,
#    1313                 "stream_options": stream_options,
#    1314                 "temperature": temperature,
#    1315                 "tool_choice": tool_choice,
#    1316                 "tools": tools,
#    1317                 "top_logprobs": top_logprobs,
#    1318                 "top_p": top_p,
#    1319                 "user": user,
#    1320                 "verbosity": verbosity,
#    1321                 "web_search_options": web_search_options,
#    1322             },
#    1323             completion_create_params.CompletionCreateParamsStreaming
#    1324             if stream
#    1325             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1326         ),
#    1327         options=make_request_options(
#    1328             extra_headers=extra_headers,
#    1329             extra_query=extra_query,
#    1330             extra_body=extra_body,
#    1331             timeout=timeout,
#    1332             security={"bearer_auth": True},
#    1333         ),
#    1334         cast_to=ChatCompletion,
#    1335         stream=stream or False,
#    1336         stream_cls=Stream[ChatCompletionChunk],
#    1337     )
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Sujoy Garai\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1072, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1069         continue
#    1071     log.debug("Raising connection error")
# -> 1072     raise APIConnectionError(request=request) from err
#    1074 log.debug(
#    1075     'HTTP Response: %s %s "%i %s" %s',
#    1076     request.method,
#    (...)   1080     response.headers,
#    1081 )
#    1082 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = nvidia_api_key
)

completion = client.chat.completions.create(
  model="openai/gpt-oss-120b",
  messages=[{"role":"user","content":"2 + 2 = ?"}],
  temperature=1,
  top_p=1,
  max_tokens=4096,
  stream=False
)

reasoning = getattr(completion.choices[0].message, "reasoning_content", None)
if reasoning:
  print(reasoning)
print(completion.choices[0].message.content)
# Out:
# The user asks a simple arithmetic: 2 + 2 = ?. Should answer: 4. Possibly also explain.
# 2 + 2 = 4.
